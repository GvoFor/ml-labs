# %% [markdown]
# # ML Lab1
# #### Author: Pumnia Mykhailo, KM-22
# ---

# %% [markdown]
# Imports

# %%
import pandas as pd

# %% [markdown]
# Step 1. Open [Weather.csv](./Weather.csv) file

# %%
data = pd.read_csv('./Weather.csv')
data
# Out:
#              CET  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0       1997-1-1               7.0                4.0               2.0
# 1       1997-1-2               7.0                3.0               0.0
# 2       1997-1-3               5.0                3.0               2.0
# 3       1997-1-4               7.0                3.0              -1.0
# 4       1997-1-5               2.0                0.0              -1.0
# ...          ...               ...                ...               ...
# 6807  2015-12-27              14.0                7.0              -1.0
# 6808  2015-12-28              15.0                8.0               2.0
# 6809  2015-12-29              11.0                8.0               5.0
# 6810  2015-12-30               9.0                8.0               6.0
# 6811  2015-12-31              12.0               10.0               7.0
#
#       Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity   Mean Humidity  \
# ...

# %% [markdown]
# Step 2. Determine and print out number of records and fields

# %%
(records_n, fields_n) = data.shape
print(f'Number of records: {records_n}')
print(f'Number of fields: {fields_n}')
# Out:
# Number of records: 6812
# Number of fields: 23

# %% [markdown]
# Step 3. Print out 5 records starting with `M`-th and every `N`-th record.
# My birthday is in November, so `M = 11`, and `N = 300 * M =  3300`

# %%
M = 11
N = 300 * M

data[M::N]
# Out:
#             CET  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 11    1997-1-12              17.0               10.0               3.0
# 3311   2006-6-1              25.0               17.0               9.0
# 6611  2015-6-14              22.0               18.0              13.0
#
#       Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity   Mean Humidity  \
# 11           8.0             6.0            3.0         100.0            84.0
# 3311         3.0            -2.0           -5.0          46.0            31.0
# 6611         8.0             6.0            4.0          63.0            42.0
#
#        Min Humidity  ...   Max VisibilityKm   Mean VisibilityKm  \
# 11             55.0  ...               10.0                10.0
# 3311           14.0  ...               10.0                10.0
# 6611           22.0  ...               31.0                18.0
#
#        Min VisibilitykM   Max Wind SpeedKm/h   Mean Wind SpeedKm/h  \
# ...

# %% [markdown]
# Step 4. Determine and print out types of the fields

# %%
data.dtypes
# Out:
# CET                             object
# Max TemperatureC               float64
# Mean TemperatureC              float64
# Min TemperatureC               float64
# Dew PointC                     float64
# MeanDew PointC                 float64
# Min DewpointC                  float64
# Max Humidity                   float64
#  Mean Humidity                 float64
#  Min Humidity                  float64
#  Max Sea Level PressurehPa       int64
#  Mean Sea Level PressurehPa      int64
#  Min Sea Level PressurehPa       int64
#  Max VisibilityKm              float64
#  Mean VisibilityKm             float64
#  Min VisibilitykM              float64
#  Max Wind SpeedKm/h              int64
#  Mean Wind SpeedKm/h             int64
#  Max Gust SpeedKm/h            float64
# Precipitationmm                float64
#  CloudCover                    float64
#  Events                         object
# WindDirDegrees                   int64
# dtype: object

# %%
# Fix fields names
data.columns = data.columns.str.strip()

# %% [markdown]
# Step 5. Replace `CET` filed with new text fields for day, month and year.
# Note: day and month should be written in 2-digital format.

# %%
data[['Year', 'Month', 'Day']] = data['CET'].str.split('-', expand=True)
data['Month'] = data['Month'].apply(lambda x: x if len(x) > 1 else f'0{x}')
data['Day'] = data['Day'].apply(lambda x: x if len(x) > 1 else f'0{x}')
data.drop(columns=['CET'], inplace=True)
data
# Out:
#       Max TemperatureC  Mean TemperatureC  Min TemperatureC  Dew PointC  \
# 0                  7.0                4.0               2.0         5.0
# 1                  7.0                3.0               0.0         6.0
# 2                  5.0                3.0               2.0         5.0
# 3                  7.0                3.0              -1.0        -2.0
# 4                  2.0                0.0              -1.0         2.0
# ...                ...                ...               ...         ...
# 6807              14.0                7.0              -1.0         6.0
# 6808              15.0                8.0               2.0         8.0
# 6809              11.0                8.0               5.0         9.0
# 6810               9.0                8.0               6.0         7.0
# 6811              12.0               10.0               7.0        10.0
#
#       MeanDew PointC  Min DewpointC  Max Humidity  Mean Humidity  \
# ...

# %% [markdown]
# Step 6. Determine and print out:
# 1. A number of days with empty `Events` field;
# 2. The day (and wind speeds in this day) with minimal mean humidity;
# 3. The months with mean temparature in range from 0 to 5 degrees;

# %%
n = data['Events'].isna().sum()
print(f'Number of days without any event: {n}')
# Out:
# Number of days without any event: 5014

# %%
min_mean_humidity = data['Mean Humidity'].min()
result = data[data['Mean Humidity'] == min_mean_humidity]
result[['Day', 'Max Wind SpeedKm/h', 'Mean Wind SpeedKm/h', 'Mean Humidity']]
# Out:
#      Day  Max Wind SpeedKm/h  Mean Wind SpeedKm/h  Mean Humidity
# 3012  06                  14                   10           15.0

# %%
mean_temperature = data['Mean TemperatureC']
result = data[(mean_temperature >= 0) & (mean_temperature <= 5)]
result[['Month', 'Mean TemperatureC']]
# Out:
#      Month  Mean TemperatureC
# 0       01                4.0
# 1       01                3.0
# 2       01                3.0
# 3       01                3.0
# 4       01                0.0
# ...    ...                ...
# 6486    02                4.0
# 6487    02                4.0
# 6497    02                5.0
# 6520    03                4.0
# 6521    03                4.0
#
# [654 rows x 2 columns]

# %% [markdown]
# Step 7. Determine and print out:
# 1. A mean maximum temperature for each day during all the years;
# 2. A number of days with a fog for all years;

# %%
# v1
data.groupby(['Month', 'Day'])['Max TemperatureC'].mean().reset_index(name='Mean Max TemperatureC')

# v2
# result = data.groupby(['Month', 'Day'])['Max TemperatureC'].mean().reset_index(name='Mean Max TemperatureC')
# result['Day'] = result.index + 1
# result.drop(columns=['Month'], inplace=True)
# result
# Out:
#     Month Day  Mean Max TemperatureC
# 0      01  01               9.894737
# 1      01  02              10.833333
# 2      01  03              10.500000
# 3      01  04              11.000000
# 4      01  05              10.388889
# ..    ...  ..                    ...
# 361    12  27              10.105263
# 362    12  28              10.000000
# 363    12  29               9.526316
# 364    12  30              10.526316
# 365    12  31              10.105263
#
# [366 rows x 3 columns]

# %%
is_rain_event = data['Events'].str.contains('Rain', na=False)
data[is_rain_event].groupby('Year').size().reset_index(name='Number of days')
# Out:
#     Year  Number of days
# 0   1997             102
# 1   1998              76
# 2   1999              80
# 3   2000              52
# 4   2001              69
# 5   2002              85
# 6   2003              77
# 7   2004              70
# 8   2005              56
# 9   2006              83
# 10  2007              70
# 11  2008              87
# 12  2009              73
# 13  2010             102
# 14  2011              84
# 15  2012              62
# 16  2013             103
# 17  2014             101
# 18  2015              68

# %% [markdown]
# Step 8. Plot a bar chart for `Events` number

# %%
p = data.groupby('Year')['Events'].count().plot.bar()
p.set_ylabel('Events per Year')
# Out:
# Text(0, 0.5, 'Events per Year')

# %% [markdown]
# Step 9. Plot a pie chart of wind directions (the sector on the chart should correspond to one of the eight directions - north, south, east, west and all the intermediate)
#
# Note: Here I'll asume that East points to the right, so its sector contains degrees in range (-22.5, 22.5], and then degrees increasing in counter-clockwise (so next sector will be North-East, then North and so on)

# %%
DIRECTIONS = ['East', 'North-East', 'North', 'North-West', 'West', 'South-West', 'South', 'South-East']
SECTOR_DEGREES = 360 / len(DIRECTIONS)
HALF_SECTOR_DEGREES = SECTOR_DEGREES / 2

def get_dir(deg):
  i = int((deg + HALF_SECTOR_DEGREES) % 360 / SECTOR_DEGREES)
  return DIRECTIONS[i]


valid_wind_dir_degrees = data['WindDirDegrees'].where(lambda x: (x >= 0) & (x <= 360)).dropna()
p = valid_wind_dir_degrees.apply(get_dir).value_counts()[DIRECTIONS].plot.pie(
  autopct="%.2f"
)
p.set_ylabel('')
p.set_title('Wind directions')
# Out:
# Text(0.5, 1.0, 'Wind directions')

# %% [markdown]
# Step 10. Plot on the same chart:
# 1. The mean maximum temperature for each month of each year
# 2. The mean minimum dew point for each month of each year.

# %%
mean_values = data.groupby(['Year', 'Month'])[['Max TemperatureC', 'Min DewpointC']].mean()
mean_values.plot.line(subplots=True)
# Out:
# array([<Axes: xlabel='Year,Month'>, <Axes: xlabel='Year,Month'>],
#       dtype=object)
